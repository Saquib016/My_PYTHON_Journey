# %%
import pandas as pd

# %%
info = {
    "Name":["Rahul","Harshita","Shradha"],
    "CGPA":[9.5,7.5,8.5]
    
}
df = pd.DataFrame(info)
print(df)
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Harshita   7.5
# 2   Shradha   8.5

# %%
df
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Harshita   7.5
# 2   Shradha   8.5

# %%
#series
s= pd.Series([2,3,4,5,6],index = ["A",'b','5',2,"99"])
s
s.index
print(s.loc["A"],s.iloc[0])
news= s.drop("A")
print(s,news)
# Out:
# 2 2
# A     2
# b     3
# 5     4
# 2     5
# 99    6
# dtype: int64 b     3
# 5     4
# 2     5
# 99    6
# dtype: int64

# %%
#data frames
info = {
    "Name":["Adam","Eve","Bob"],
    "Age" : [23,24,25],
    "GPA" : [9.5,8.6,7.2]
}
df = pd.DataFrame(info)
print(type(pd.DataFrame(info)))
print(df.index)
print(df.columns)
#using List Of List
df = pd.DataFrame([["Adam",23],["Bob",23],["Eve",23]],columns = ["Name","Age"],index = ["X","y","Z"])
print(df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'Age', 'GPA'], dtype='str')
#    Name  Age
# X  Adam   23
# y   Bob   23
# Z   Eve   23

# %%
#csv Data
df = pd.read_csv("employee_data.csv")
print(df,type(df))
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.DataFrame'>
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
#json Data
df = pd.read_json("Panda_Data.json")
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
#methods
df.head() #Starting 5 rows
df.tail() #last 5 rows or manual rows if provide input i.e df.tail(5)
df.sample(7)
df.info()
df.shape
df.describe()
df.columns
df.nunique()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     str
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     str
#  4   Salary      10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 532.0 bytes
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64

# %%
#AQi data set
df = pd.read_csv("globalAirQuality.csv")
df.head()
df.tail()
df.describe()
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
#selecting DAta
df["city"]
df[["city","aqi"]]
df.loc[0]
# df.loc[0:2] #2 included here
# df.iloc[2]
df.iloc[0:2] #2 not included
df.loc[0:2,["city","aqi"]]
df.columns
df.iloc[0:2,[2,11]] #0 to 2 index row with value where index is 2  i.e city index is 2 check using column
df.at[0,"city"]
df.iloc[0,2]
# Out:
# 'New York'

# %%
#Filtering Data
df[df["aqi"]>100] #direct relational
df[(df["aqi"]>100)&(df["temperature"]>30) ]
df[df["aqi"]>100][["city","aqi"]]
ai_data = df[df["aqi"]>100][["city","aqi"]]
ai_data.iloc[2]
# ai_data.loc[2] #will show error cause 2 is not there in preseved label but index to hoga hi.
ai_data.loc[0] #this is present so it will print
# Out:
# city    New York
# aqi          108
# Name: 0, dtype: object

# %%
ai_data
# Out:
#            city  aqi
# 0      New York  108
# 3      New York  158
# 6      New York  155
# 7      New York  115
# 8      New York  121
# ...         ...  ...
# 17991    Zurich  104
# 17993    Zurich  153
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
#
# [9721 rows x 2 columns]

# %%
#Filter using Queries
aqi_greater = 100
df.query("aqi>100 & latitude!=40.713" )[["city","aqi"]]
df.query("aqi>@aqi_greater & temperature>30" )[["city","aqi"]]
# Out:
#            city  aqi
# 6      New York  155
# 7      New York  115
# 14     New York  121
# 17     New York  127
# 25     New York  113
# ...         ...  ...
# 17947    Zurich  107
# 17950    Zurich  140
# 17975    Zurich  111
# 17976    Zurich  146
# 17991    Zurich  104
#
# [2384 rows x 2 columns]

# %%
#Clean Data
#Handle Missing Value
df = pd.read_csv("raw_data.csv")
df.isnull()
df.isna()
df.isnull().sum()
df.dropna() #drop row
df.dropna(axis = 1) #drop column
df.fillna(69) #missing value change with the given value
cleaned_data = df.copy()
cleaned_data["age"] = cleaned_data["age"].fillna(cleaned_data["age"].mean())
cleaned_data["age"]
df.ffill() #uper waala neeche
df.bfill() #neeche waala uper
# Out:
#    Unnamed: 0  id          name   age country   gender   income
# 0           4   4  Maria Garcia  34.0   Spain   Female      0.0
# 1           9   9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 2           3   3          Alex   0.0     USA  Unknown  47000.0
# 3           5   5        Li Wei  27.0   China     Male  51000.0
# 4           0   1      John Doe  29.0     USA     Male  55000.0
# 5          10  10   Emily Davis  31.0     USA        0  58000.0
# 6           2   2    Jane Smith   0.0  Canada   Female  62000.0
# 7           8   8    Rachel Lee  29.0     USA   Female  62000.0
# 8           7   7    Ahmed Khan  38.0       0     Male  68000.0
# 9           6   6             0  45.0   India   Female  73000.0

# %%
#Handle Duplicates
df.duplicated()
df.drop_duplicates(inplace = True)

# %%
df = pd.read_csv("globalAirQuality.csv")
date_time = pd.Series([pd.to_datetime("2026-12-31")])
print(date_time.dtypes)
# Out:
# datetime64[us]

# %%
#Handling Data Types
df = pd.read_csv("raw_data.csv")
df2 = df.copy() #we create copy and fill missing so that it won't throw error and when we change type every value can change cause if mising then it won't change and throw an  error
df2 = df2.fillna(0)
df2["age"] = df2["age"].astype("int64").copy()
df2.dtypes
df2
# Out:
#    Unnamed: 0  id          name  age country   gender   income
# 0           4   4  Maria Garcia   34   Spain   Female      0.0
# 1           9   9   Carlos Ruiz    0  Mexico     Male  45000.0
# 2           3   3          Alex    0     USA  Unknown  47000.0
# 3           5   5        Li Wei   27   China     Male  51000.0
# 4           0   1      John Doe   29     USA     Male  55000.0
# 5          10  10   Emily Davis   31     USA        0  58000.0
# 6           2   2    Jane Smith    0  Canada   Female  62000.0
# 7           8   8    Rachel Lee   29     USA   Female  62000.0
# 8           7   7    Ahmed Khan   38       0     Male  68000.0
# 9           6   6             0   45   India   Female  73000.0

# %%
#Handle Stirng
df = pd.read_csv("raw_data.csv")
df["gender"].str.upper()
df["gender"].str.capitalize()
# Out:
# 0     Female
# 1       Male
# 2    Unknown
# 3       Male
# 4       Male
# 5          0
# 6     Female
# 7     Female
# 8       Male
# 9     Female
# Name: gender, dtype: str

# %%
#python part2
df2 = df.copy()
#Featuring
df2["tax"] = df2["income"].apply(lambda x: "20%" if x >= 60000 else "10%").copy()
gender_map = {"Male":"M","Female":"F","Unknown":"U"}
df2["gender"] = df2["gender"].map(gender_map).copy()
df2.assign(new_income = df2["income"]*1.1)
df2["country"] = df2["country"].replace("USA","US")

# %%
#transforming
df2 = df2.drop(columns=["Unnamed: 0"])

df2.columns = ["Id", "Name", "Age", "Country", "Gender", "Income", "Tax"]

df2 = df2.rename(columns={"Income": "Salary"}).copy()

sorted_df = df2.sort_values("Salary", ascending=False)
sorted_df = sorted_df.reset_index(drop=True)

sorted_df["Ranking"] = sorted_df["Salary"].rank(
    ascending=False,
    method="min"
)

sorted_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 #transforming
# ----> 2 df2 = df2.drop(columns=["Unnamed: 0"])
#       3
#       4 df2.columns = ["Id", "Name", "Age", "Country", "Gender", "Income", "Tax"]
#       5
#
# File ~\.conda\envs\primeAIML\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~\.conda\envs\primeAIML\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
#TASK: Shift Id Column to End
df2 = df.copy()
new_col = [col for col in df2.columns if col != "id"] + ["id"]
df2[new_col]
# Out:
#    Unnamed: 0          name   age country   gender   income  id
# 0           4  Maria Garcia  34.0   Spain   Female      0.0   4
# 1           9   Carlos Ruiz   0.0  Mexico     Male  45000.0   9
# 2           3          Alex   0.0     USA  Unknown  47000.0   3
# 3           5        Li Wei  27.0   China     Male  51000.0   5
# 4           0      John Doe  29.0     USA     Male  55000.0   1
# 5          10   Emily Davis  31.0     USA        0  58000.0  10
# 6           2    Jane Smith   0.0  Canada   Female  62000.0   2
# 7           8    Rachel Lee  29.0     USA   Female  62000.0   8
# 8           7    Ahmed Khan  38.0       0     Male  68000.0   7
# 9           6             0  45.0   India   Female  73000.0   6

# %%
#Write to CSV
df2 = df.copy()
df2 = df2.drop_duplicates()
df2 = df2.fillna(0)
df2 = df2.sort_values("income")
df2.reset_index(drop = True)
df2.to_csv("sorted_data.csv")

# %%
#Grouping And Aggrigation
df.groupby("country")["income"].mean()
df.groupby("country")["income"].min()
df.groupby("country")["income"].max()
print(df.groupby("country"))
df.groupby("country")["income"].agg(["mean","min","max"])
# Out:
# ...
#             mean      min      max
# country
# 0        68000.0  68000.0  68000.0
# Canada   62000.0  62000.0  62000.0
# China    51000.0  51000.0  51000.0
# India    73000.0  73000.0  73000.0
# Mexico   45000.0  45000.0  45000.0
# Spain        0.0      0.0      0.0
# USA      55500.0  47000.0  62000.0

# %%
#Melt and Pivot
df = pd.DataFrame({
    "country":["USA","USA","India","India"],
    "year":[2020,2021,2020,2021],
    "sales": [100,120,90,110],
    "profit":[20,25,18,22],
    "tax":[20,3,59,67]
})
melted_df = df.melt(
    id_vars = ["country","year"],
    value_vars = ["sales","profit"],
    var_name = "metrics",
    value_name = "value"
)
original = melted_df.pivot(
    index = ["country","year"],
    columns = "metrics",
    values = "value"
)

# %%
melted_df
# Out:
#   country  year metrics  value
# 0     USA  2020   sales    100
# 1     USA  2021   sales    120
# 2   India  2020   sales     90
# 3   India  2021   sales    110
# 4     USA  2020  profit     20
# 5     USA  2021  profit     25
# 6   India  2020  profit     18
# 7   India  2021  profit     22

# %%
original
# Out:
# metrics       profit  sales
# country year
# India   2020      18     90
#         2021      22    110
# USA     2020      20    100
#         2021      25    120

# %%
#Basic Visualization with pandas
df = pd.read_csv("employee_data.csv")
df["Age"].hist()
df.plot(kind= "scatter",x = "Age",y = "Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
#Merging and Joining The Data
#In mam's Code cause there is some info too

# %%
#Data Concatination
df1 = pd.DataFrame({
    "id":[1,2,3],
    "name":["Charlie","Fester","Gillian"]
})
df2 = pd.DataFrame({
   "id":[4,5,6],
    "name":["Adam","Eve","Gillian"] 
})
pd.concat([df1,df2],ignore_index=True)
pd.concat([df1,df2],axis=1)
# Out:
#    id     name  id     name
# 0   1  Charlie   4     Adam
# 1   2   Fester   5      Eve
# 2   3  Gillian   6  Gillian

# %%
df1
# Out:
#    id     name
# 0   1  Charlie
# 1   2   Fester
# 2   3  Gillian

# %%
df2
# Out:
#    id     name
# 0   4     Adam
# 1   5      Eve
# 2   6  Gillian
